# %% [markdown]
# # Combining Dataframes

# %%
import pandas as pd

# %%
df_crime=pd.read_csv('Chicago_Crime_Data-v2.csv')
df_schools=pd.read_csv('Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012-v3.csv')
df_census=pd.read_csv('Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012-v2.csv')

# %%
df_crime.head()
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE   False     False  ...  14.0
# 1                         OTHER   False     False  ...  27.0
# ...

# %%
df_schools.head()
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
# 2                                 ES     8010 S Kostner Ave   Chicago    IL
# 3                                 ES     4619 S Wolcott Ave   Chicago    IL
# 4                                 HS        3630 S Wells St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
df_census.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# ...

# %%
df_schools1=df_schools[df_schools['COMMUNITY_AREA_NUMBER']==1]
df_schools1=df_schools[df_schools['COMMUNITY_AREA_NUMBER']==2]

# %%
df_combined=pd.concat([df_schools1, df_schools2], keys=['CAN 1', 'CAN 2'])
df_combined
# Out:
#            School ID                                     NAME_OF_SCHOOL  \
# CAN 1 150     609918                     Eugene Field Elementary School
#       304     609865                 Jordan Elementary Community School
#       317     610022                     Joyce Kilmer Elementary School
#       399     610284                        New Field Elementary School
#       464     609733                       Roger C Sullivan High School
#       489     609933        Stephen F Gale Elementary Community Academy
# CAN 2 97      609804                     Daniel Boone Elementary School
#       107     609859                   DeWitt Clinton Elementary School
#       184     609779  George Armstrong International Studies Element...
#       382     610011             Minnie Mars Jamieson Elementary School
#       435     610147                    Philip Rogers Elementary School
#       488     609880        Stephen Decatur Classical Elementary School
# ...

# %%
df_combined.loc['CAN 2']
# Out:
#      School ID                                     NAME_OF_SCHOOL  \
# 97      609804                     Daniel Boone Elementary School
# 107     609859                   DeWitt Clinton Elementary School
# 184     609779  George Armstrong International Studies Element...
# 382     610011             Minnie Mars Jamieson Elementary School
# 435     610147                    Philip Rogers Elementary School
# 488     609880        Stephen Decatur Classical Elementary School
# 491     609724                       Stephen T Mather High School
# 492     610191                Stone Elementary Scholastic Academy
# 530     610542                       West Ridge Elementary School
#
#     Elementary, Middle, or High School          Street Address     City State  \
# 97                                  ES   6710 N Washtenaw Ave   Chicago    IL
# 107                                 ES   6110 N Fairfield Ave   Chicago    IL
# ...

# %%
df_schools1=df_schools[df_schools['COMMUNITY_AREA_NUMBER']==1][['NAME_OF_SCHOOL', 'COMMUNITY_AREA_NUMBER', 'COMMUNITY_AREA_NAME']]

# %%
df_schools1
# Out:
#                                   NAME_OF_SCHOOL  COMMUNITY_AREA_NUMBER  \
# 150               Eugene Field Elementary School                      1
# 304           Jordan Elementary Community School                      1
# 317               Joyce Kilmer Elementary School                      1
# 399                  New Field Elementary School                      1
# 464                 Roger C Sullivan High School                      1
# 489  Stephen F Gale Elementary Community Academy                      1
#
#     COMMUNITY_AREA_NAME
# 150         ROGERS PARK
# 304         ROGERS PARK
# 317         ROGERS PARK
# 399         ROGERS PARK
# 464         ROGERS PARK
# 489         ROGERS PARK

# %%
df_combined=pd.concat([df_schools1, df_schools2], join='inner', ignore_index=True)
df_combined
# Out:
#                                        NAME_OF_SCHOOL  COMMUNITY_AREA_NUMBER  \
# 0                      Eugene Field Elementary School                      1
# 1                  Jordan Elementary Community School                      1
# 2                      Joyce Kilmer Elementary School                      1
# 3                         New Field Elementary School                      1
# 4                        Roger C Sullivan High School                      1
# 5         Stephen F Gale Elementary Community Academy                      1
# 6                      Daniel Boone Elementary School                      2
# 7                    DeWitt Clinton Elementary School                      2
# 8   George Armstrong International Studies Element...                      2
# 9              Minnie Mars Jamieson Elementary School                      2
# 10                    Philip Rogers Elementary School                      2
# ...

# %%
df_pov=df_census[['COMMUNITY_AREA_NUMBER', 'PERCENT HOUSEHOLDS BELOW POVERTY']]
df_pov.head()
# Out:
#    COMMUNITY_AREA_NUMBER  PERCENT HOUSEHOLDS BELOW POVERTY
# 0                    1.0                              23.6
# 1                    2.0                              17.2
# 2                    3.0                              24.0
# 3                    4.0                              10.9
# 4                    5.0                               7.5

# %%
df_merge1=pd.merge(df_pov, df_combined, on='COMMUNITY_AREA_NUMBER', how='left', indicator=True, validate='one_to_many')
df_merge1
# Out:
#     COMMUNITY_AREA_NUMBER  PERCENT HOUSEHOLDS BELOW POVERTY  \
# 0                     1.0                              23.6
# 1                     1.0                              23.6
# 2                     1.0                              23.6
# 3                     1.0                              23.6
# 4                     1.0                              23.6
# ..                    ...                               ...
# 86                   74.0                               3.4
# 87                   75.0                              13.2
# 88                   76.0                              15.4
# 89                   77.0                              18.2
# 90                    NaN                              19.7
#
#                         NAME_OF_SCHOOL COMMUNITY_AREA_NAME     _merge
# 0       Eugene Field Elementary School         ROGERS PARK       both
# 1   Jordan Elementary Community School         ROGERS PARK       both
# ...
