# %% [markdown]
# # Data Types

# %%
import pandas as pd
import numpy as np

# %%
df_crime=pd.read_csv('Chicago_Crime_Data-v2.csv')
df_schools=pd.read_csv('Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012-v3.csv')
df_census=pd.read_csv('Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012-v2.csv')

# %%
df_crime.head()
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE   False     False  ...  14.0
# 1                         OTHER   False     False  ...  27.0
# ...

# %%
df_schools.head()
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
# 2                                 ES     8010 S Kostner Ave   Chicago    IL
# 3                                 ES     4619 S Wolcott Ave   Chicago    IL
# 4                                 HS        3630 S Wells St   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %% [markdown]
# ### Text Data

# %%
df_schools['City']=df_schools['City'].str.upper()
df_schools.head()
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   CHICAGO    IL
# 1                                 ES  7511 S South Shore Dr   CHICAGO    IL
# 2                                 ES     8010 S Kostner Ave   CHICAGO    IL
# 3                                 ES     4619 S Wolcott Ave   CHICAGO    IL
# 4                                 HS        3630 S Wells St   CHICAGO    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
df_schools.columns = df_schools.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(',', '')
df_schools.head()
# Out:
#    school_id                                     name_of_school  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   elementary_middle_or_high_school          street_address     city state  \
# 0                               ES        615 W Kemper Pl   CHICAGO    IL
# 1                               ES  7511 S South Shore Dr   CHICAGO    IL
# 2                               ES     8010 S Kostner Ave   CHICAGO    IL
# 3                               ES     4619 S Wolcott Ave   CHICAGO    IL
# 4                               HS        3630 S Wells St   CHICAGO    IL
#
#    zip_code    phone_number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
# 2     60652  (773) 535-2280
# ...

# %%
crime_cats=pd.Series(df_crime['PRIMARY_TYPE'].unique()).str.cat(sep=', ')
crime_cats
# Out:
# 'THEFT, BATTERY, CRIMINAL DAMAGE, NARCOTICS, OTHER OFFENSE, ASSAULT, BURGLARY, MOTOR VEHICLE THEFT, DECEPTIVE PRACTICE, ROBBERY, CRIMINAL TRESPASS, PROSTITUTION, WEAPONS VIOLATION, PUBLIC PEACE VIOLATION, OFFENSE INVOLVING CHILDREN, CRIM SEXUAL ASSAULT, SEX OFFENSE, INTERFERENCE WITH PUBLIC OFFICER, GAMBLING, LIQUOR LAW VIOLATION, ARSON, HOMICIDE, KIDNAPPING, INTIMIDATION, STALKING, OBSCENITY, CONCEALED CARRY LICENSE VIOLATION, PUBLIC INDECENCY, NON-CRIMINAL, OTHER NARCOTIC VIOLATION, HUMAN TRAFFICKING, NON - CRIMINAL, RITUALISM, NON-CRIMINAL (SUBJECT SPECIFIED), DOMESTIC VIOLENCE'

# %% [markdown]
# ### Missing Data

# %%
df_crime_groups=df_crime[['PRIMARY_TYPE', 'ARREST', 'ID']].groupby(['PRIMARY_TYPE', 'ARREST']).count()
df_crime_groups.reset_index(inplace=True)
df_pivot=df_crime_groups.pivot(index='PRIMARY_TYPE', columns='ARREST', values='ID')
df_pivot.head()
# Out:
# ARREST                             False  True
# PRIMARY_TYPE
# ARSON                                2.0    NaN
# ASSAULT                             23.0    9.0
# BATTERY                             72.0   20.0
# BURGLARY                            29.0    1.0
# CONCEALED CARRY LICENSE VIOLATION    NaN    1.0

# %%
df_pivot[df_pivot[False].notna() & df_pivot[True].notna()].head()
# Out:
# ARREST               False  True
# PRIMARY_TYPE
# ASSAULT               23.0    9.0
# BATTERY               72.0   20.0
# BURGLARY              29.0    1.0
# CRIM SEXUAL ASSAULT    2.0    1.0
# CRIMINAL DAMAGE       52.0    6.0

# %%
df_pivot[df_pivot[False].isna() | df_pivot[True].isna()].head()
# Out:
# ARREST                             False  True
# PRIMARY_TYPE
# ARSON                                2.0    NaN
# CONCEALED CARRY LICENSE VIOLATION    NaN    1.0
# DOMESTIC VIOLENCE                    NaN    1.0
# GAMBLING                             NaN    2.0
# HUMAN TRAFFICKING                    1.0    NaN

# %%
df_pivot.fillna(0).head()
# Out:
# ARREST                             False  True
# PRIMARY_TYPE
# ARSON                                2.0    0.0
# ASSAULT                             23.0    9.0
# BATTERY                             72.0   20.0
# BURGLARY                            29.0    1.0
# CONCEALED CARRY LICENSE VIOLATION    0.0    1.0

# %%
df_pivot.dropna(axis=0).head()
# Out:
# ARREST               False  True
# PRIMARY_TYPE
# ASSAULT               23.0    9.0
# BATTERY               72.0   20.0
# BURGLARY              29.0    1.0
# CRIM SEXUAL ASSAULT    2.0    1.0
# CRIMINAL DAMAGE       52.0    6.0

# %%
df_pivot.dropna(axis=1).head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [ARSON, ASSAULT, BATTERY, BURGLARY, CONCEALED CARRY LICENSE VIOLATION]

# %%
# Does not work: cannot convert NA to int64
df_pivot.astype('int64')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-34402e91ca71> in <module>
# ----> 1 df_pivot.astype('int64')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
df_pivot.astype('Int64') # works
# Out:
# ARREST                             False  True
# PRIMARY_TYPE
# ARSON                                  2    NaN
# ASSAULT                               23      9
# BATTERY                               72     20
# BURGLARY                              29      1
# CONCEALED CARRY LICENSE VIOLATION    NaN      1
# CRIM SEXUAL ASSAULT                    2      1
# CRIMINAL DAMAGE                       52      6
# CRIMINAL TRESPASS                      2     13
# DECEPTIVE PRACTICE                    14      6
# DOMESTIC VIOLENCE                    NaN      1
# GAMBLING                             NaN      2
# HOMICIDE                               1      1
# HUMAN TRAFFICKING                      1    NaN
# INTERFERENCE WITH PUBLIC OFFICER       1      1
# INTIMIDATION                           1    NaN
# KIDNAPPING                             1    NaN
# LIQUOR LAW VIOLATION                 NaN      2
# MOTOR VEHICLE THEFT                   23      1
# ...
