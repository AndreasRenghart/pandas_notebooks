# %% [markdown]
# # Data Selection and Indexing

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df=pd.read_csv('Chicago_Crime_Data-v2.csv')

# %%
df.head()
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE   False     False  ...  14.0
# 1                         OTHER   False     False  ...  27.0
# ...

# %%
df.dtypes
# Out:
# ID                         int64
# CASE_NUMBER               object
# DATE                      object
# BLOCK                     object
# IUCR                      object
# PRIMARY_TYPE              object
# DESCRIPTION               object
# LOCATION_DESCRIPTION      object
# ARREST                      bool
# DOMESTIC                    bool
# BEAT                       int64
# DISTRICT                   int64
# WARD                     float64
# COMMUNITY_AREA_NUMBER    float64
# FBICODE                   object
# X_COORDINATE             float64
# Y_COORDINATE             float64
# YEAR                       int64
# UPDATEDON                 object
# LATITUDE                 float64
# LONGITUDE                float64
# LOCATION                  object
# dtype: object

# %%
df[['ID', 'DATE']]
# Out:
#            ID                    DATE
# 0     3512276  08/28/2004 05:50:56 PM
# 1     3406613  06/26/2004 12:40:00 PM
# 2     8002131  04/04/2011 05:45:00 AM
# 3     7903289  12/30/2010 04:30:00 PM
# 4    10402076  02/02/2016 07:30:00 PM
# ..        ...                     ...
# 528  10453948  03/01/2016 12:00:00 AM
# 529  10397129  01/29/2016 03:30:00 PM
# 530   3269495  11/08/2003 04:54:15 PM
# 531  10840565  02/06/2017 01:20:00 PM
# 532   1326195  01/11/2001 02:30:41 AM
#
# [533 rows x 2 columns]

# %%
df.loc[0:5,'ID':'DATE']
# Out:
#          ID CASE_NUMBER                    DATE
# 0   3512276    HK587712  08/28/2004 05:50:56 PM
# 1   3406613    HK456306  06/26/2004 12:40:00 PM
# 2   8002131    HT233595  04/04/2011 05:45:00 AM
# 3   7903289    HT133522  12/30/2010 04:30:00 PM
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM
# 5   7732712    HS540106  09/29/2010 07:59:00 AM

# %%
df.loc[df['PRIMARY_TYPE']=='THEFT']
# Out:
#            ID CASE_NUMBER                    DATE                     BLOCK  \
# 0     3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1     3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2     8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3     7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4    10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
# ..        ...         ...                     ...                       ...
# 101  10619033    HZ372381  07/25/2016 07:00:00 PM      023XX W JACKSON BLVD
# 102  10787573    HZ556726  12/19/2016 08:00:00 AM           005XX W 95TH ST
# 103   5613705    HN421595  06/13/2007 09:00:00 AM        058XX S ARCHER AVE
# 104   3398799    HK454598  06/25/2004 07:00:00 AM       017XX N NATCHEZ AVE
# 105   2355174    HH657809  09/18/2002 08:00:00 PM         102XX S HOXIE AVE
#
#     IUCR PRIMARY_TYPE                    DESCRIPTION  \
# ...

# %%
df.set_index('ID', inplace=True)
df.head()
# Out:
#          CASE_NUMBER                    DATE                     BLOCK IUCR  \
# ID
# 3512276     HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE  890
# 3406613     HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE  820
# 8002131     HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE  820
# 7903289     HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE  840
# 10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST  820
#
#          PRIMARY_TYPE                    DESCRIPTION  \
# ID
# 3512276         THEFT                  FROM BUILDING
# 3406613         THEFT                 $500 AND UNDER
# 8002131         THEFT                 $500 AND UNDER
# 7903289         THEFT  FINANCIAL ID THEFT: OVER $300
# 10402076        THEFT                 $500 AND UNDER
#
#                   LOCATION_DESCRIPTION  ARREST  DOMESTIC  BEAT  ...  WARD  \
# ID                                                              ...
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#          ID CASE_NUMBER                    DATE                     BLOCK  \
# 0   3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE
# 1   3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE
# 2   8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 3   7903289    HT133522  12/30/2010 04:30:00 PM      083XX S KINGSTON AVE
# 4  10402076    HZ138551  02/02/2016 07:30:00 PM           033XX W 66TH ST
#
#   IUCR PRIMARY_TYPE                    DESCRIPTION  \
# 0  890        THEFT                  FROM BUILDING
# 1  820        THEFT                 $500 AND UNDER
# 2  820        THEFT                 $500 AND UNDER
# 3  840        THEFT  FINANCIAL ID THEFT: OVER $300
# 4  820        THEFT                 $500 AND UNDER
#
#            LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 0            SMALL RETAIL STORE   False     False  ...  14.0
# 1                         OTHER   False     False  ...  27.0
# ...

# %%
df.sample(n=5, weights='ID')
# Out:
#            ID CASE_NUMBER                    DATE                     BLOCK  \
# 2     8002131    HT233595  04/04/2011 05:45:00 AM        043XX S WABASH AVE
# 197   6806337    HR217367  03/15/2009 05:53:24 PM         051XX W KINZIE ST
# 398   7623578    HS426544  07/23/2010 06:00:00 PM       071XX S EMERALD AVE
# 260   7692354    HS498920  09/04/2010 02:22:00 PM  071XX S STONY ISLAND AVE
# 523  11233321    JB155558  02/16/2018 08:18:00 AM           036XX W 81ST ST
#
#      IUCR PRIMARY_TYPE                   DESCRIPTION  \
# 2     820        THEFT                $500 AND UNDER
# 197   486      BATTERY       DOMESTIC BATTERY SIMPLE
# 398   610     BURGLARY                FORCIBLE ENTRY
# 260  1811    NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 523  1540    OBSCENITY                OBSCENE MATTER
#
#              LOCATION_DESCRIPTION  ARREST  DOMESTIC  ...  WARD  \
# 2    NURSING HOME/RETIREMENT HOME   False     False  ...   3.0
# ...

# %%
df_type_year=df.drop_duplicates(['PRIMARY_TYPE', 'YEAR'])
df_type_year[['PRIMARY_TYPE', 'YEAR']]
# Out:
#                          PRIMARY_TYPE  YEAR
# 0                               THEFT  2004
# 2                               THEFT  2011
# 3                               THEFT  2010
# 4                               THEFT  2016
# 7                               THEFT  2005
# ..                                ...   ...
# 528                 HUMAN TRAFFICKING  2016
# 529                    NON - CRIMINAL  2016
# 530                         RITUALISM  2003
# 531  NON-CRIMINAL (SUBJECT SPECIFIED)  2017
# 532                 DOMESTIC VIOLENCE  2001
#
# [206 rows x 2 columns]
